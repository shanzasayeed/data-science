# %% [markdown]
# Matplotlib is a visualization library.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %% [markdown]
# Line Plot

# %%
x=np.linspace(0,10,200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y=np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.xlabel('this is my x label')
# Out:
# Text(0.5, 0, 'this is my x label')

# %%
plt.ylabel('this is my y data')
# Out:
# Text(0, 0.5, 'this is my y data')

# %%
plt.plot(x,y)
plt.xlabel('this is my x label')
plt.ylabel('this is my y data')
plt.title('this is my title')
plt.show()

# %%
plt.plot(x,y,'--r')

# %%
plt.plot(x,y,'b')

# %%
#change size of line
plt.figure(figsize=(15,5))
plt.plot(x,y)

# %%
#to get grid in background
plt.plot(x,y)
plt.grid()

# %%
plt.plot(x,y,'--b')
plt.grid()

# %%
x=[4,7,6,17,28,29]
y=[11,17,8,35,50,61]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# Scatter Plot

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x
# Out:
# array([0.56644881, 0.78070168, 0.3841568 , 0.77344094, 0.47084868,
#        0.11390556, 0.34086025, 0.42727566, 0.4744665 , 0.51268955,
#        0.47755298, 0.38097005, 0.17369792, 0.46792926, 0.59722726,
#        0.78933222, 0.42985203, 0.11395153, 0.16515658, 0.74750572,
#        0.86523494, 0.61450889, 0.59938777, 0.72065152, 0.08278991,
#        0.49728462, 0.64032046, 0.27616981, 0.50163909, 0.0220992 ,
#        0.20544683, 0.84213595, 0.28500451, 0.98364751, 0.23860183,
#        0.71343994, 0.67431217, 0.72803745, 0.19907145, 0.78056607,
#        0.36669359, 0.78527316, 0.66460868, 0.67515608, 0.2525979 ,
#        0.88872843, 0.40329229, 0.52287195, 0.37648485, 0.1575678 ])

# %%
y
# Out:
# array([0.81498963, 0.34254536, 0.16094538, 0.12430235, 0.75575254,
#        0.87467866, 0.88265267, 0.86301745, 0.78269603, 0.18287308,
#        0.92566108, 0.32438897, 0.97098777, 0.2990304 , 0.43155701,
#        0.37872139, 0.04211099, 0.99640982, 0.99634078, 0.48960307,
#        0.2086508 , 0.7780266 , 0.64757755, 0.80273924, 0.64589449,
#        0.52418539, 0.7026453 , 0.61548289, 0.15089014, 0.74694046,
#        0.73020853, 0.22183368, 0.53718175, 0.69385036, 0.91285871,
#        0.21790088, 0.20680722, 0.92284259, 0.71863172, 0.66039759,
#        0.87045403, 0.86484238, 0.6362799 , 0.13783875, 0.82458821,
#        0.12948876, 0.85707222, 0.11736873, 0.38658386, 0.66959421])

# %%
plt.scatter(x,y)

# %%
#c=colours
colours=np.random.rand(50)
plt.scatter(x,y,c=colours)

# %%
#instead of different colours we can give any particular colour as well
plt.scatter(x,y,c='b')

# %%
plt.scatter(x,y,c='r')

# %%
# you can see html colour code on google
plt.scatter(x,y,c='#3CB371')

# %%
plt.scatter(x,y,marker='x')

# %%
plt.scatter(x,y,marker='v')

# %%
plt.scatter(x,y,marker='o')

# %%
#s=size
sizes=np.random.rand(50)
plt.scatter(x,y,c=colours,s=sizes)

# %%
sizes=100*np.random.rand(50)
plt.scatter(x,y,c=colours,s=sizes)

# %%
#alpha is intensity of colour
sizes=100*np.random.rand(50)
plt.scatter(x,y,c=colours,s=sizes,alpha=.5)

# %%
plt.scatter(x,y,c=colours,s=sizes,alpha=.3)

# %%
plt.scatter(x,y,c=colours,s=sizes,alpha=.3)
plt.xlabel('this is x axis')
plt.ylabel('this is y axis')
plt.title('this is scatter graph')
# Out:
# Text(0.5, 1.0, 'this is scatter graph')

# %%
x=[4,7,6,17,28,29]
y=[11,17,8,35,50,61]

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y,c='r')

# %%
#list fo colours
colourr=['red','blue','green','yellow','#8B4513','purple']
plt.scatter(x,y,c=colourr)

# %% [markdown]
# When one axis is Categorical and other is numerical
#
# bar

# %%
x=['a','b','c','d','e']

# %%
y=np.random.rand(5)

# %%
x
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
y
# Out:
# array([0.33238544, 0.10507249, 0.997965  , 0.42176321, 0.73677887])

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(x,y)
plt.xlabel('this is categorical data')
plt.ylabel('this is numerical data')
plt.title("this is bar plot")
# Out:
# Text(0.5, 1.0, 'this is bar plot')

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# Histogram

# %%
data=[2,4,6,6,5,7,5,9,8,5,3,2,4,6,4,7,6,9,4,1]

# %%
plt.hist(data)
#x-axis is data and y-axis is frequency
# Out:
# (array([1., 2., 1., 4., 0., 3., 4., 2., 1., 2.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,color='r')
plt.show()

# %% [markdown]
# 3d projection

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)

# %%
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x,y,z)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.plot(x,y,z)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.bar(x,y,z)
plt.show()

# %% [markdown]
# piechart

# %%
x=[2,4,3,2,5]

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1216fb5f5e0>,
# ...
#  [Text(1.0162674857624154, 0.4209517756015988, ''),
#   Text(6.735557395310444e-17, 1.1, ''),
#   Text(-1.0788638084435536, 0.21459935421774148, ''),
#   Text(-0.7778174593052025, -0.7778174593052023, ''),
#   Text(0.6111272563215621, -0.9146165735328001, '')])
