# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.preprocessing import normalize

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
normalize(df[['sepal_length', 'sepal_width', 'petal_length']])
# Out:
# array([[0.80417236, 0.55188299, 0.2207532 ],
#        [0.82860636, 0.50731002, 0.23674468],
#        [0.80580638, 0.54863413, 0.22288262],
#        [0.80051467, 0.53947728, 0.26103739],
#        [0.79136117, 0.56978004, 0.22158113],
#        [0.78550129, 0.56730649, 0.24728744],
#        [0.78112095, 0.57735027, 0.23773246],
#        [0.8025982 , 0.54576678, 0.24077946],
#        [0.80696597, 0.53186394, 0.2567619 ],
#        [0.81814521, 0.51760207, 0.25045262],
#        [0.80409153, 0.55095161, 0.22335876],
#        [0.78741446, 0.55775191, 0.26247149],
#        [0.82319321, 0.51449576, 0.24009802],
#        [0.8026524 , 0.55999004, 0.20532968],
#        [0.81152621, 0.55967325, 0.16790197],
#        [0.77495453, 0.59821052, 0.2039354 ],
#        [0.79566782, 0.57464898, 0.19154966],
#        [0.80417236, 0.55188299, 0.2207532 ],
#        [0.80755664, 0.5383711 , 0.24085023],
#        [0.78047004, 0.5815267 , 0.22955001],
#        [0.81771265, 0.51485611, 0.25742806],
# ...

# %%
import pandas as pd

# %%
df_normalized=pd.DataFrame(normalize(df[['sepal_length', 'sepal_width', 'petal_length']]),columns=['sepal_length', 'sepal_width', 'petal_length'] )

# %%
df_normalized
# Out:
#      sepal_length  sepal_width  petal_length
# 0        0.804172     0.551883      0.220753
# 1        0.828606     0.507310      0.236745
# 2        0.805806     0.548634      0.222883
# 3        0.800515     0.539477      0.261037
# 4        0.791361     0.569780      0.221581
# ..            ...          ...           ...
# 145      0.744766     0.333477      0.578028
# 146      0.747989     0.296821      0.593642
# 147      0.734616     0.339053      0.587693
# 148      0.696849     0.382143      0.606933
# 149      0.706093     0.359030      0.610352
#
# [150 rows x 3 columns]
